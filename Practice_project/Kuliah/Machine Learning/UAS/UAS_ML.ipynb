# %% [markdown]
# # UAS Machine Learning
#
# ### Kelompok 8
# ### Anggota Kelompok
# - Muhammad Nandaarjuna Fadhillah (2109106028)
# - Ardi Setyiawan (2109106035)
# - Dicky Dwicandra (2109106038)
# - Hadie Pratama Tulili (2109106043)

# %% [markdown]
# ## Import Modul yang diperlukan

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Membaca dan melihat dataset

# %%
data = pd.read_excel('Harga Pangan.xlsx')
data.head()
# Out:
#     No           Komoditas (Rp) 01/ 01/ 2021 04/ 01/ 2021 05/ 01/ 2021  \
# 0    I                    Beras            -       11,800       11,800
# 1    1  Beras Kualitas Medium I            -       11,800       11,800
# 2   II              Daging Ayam            -       36,050       36,000
# 3    1    Daging Ayam Ras Segar            -       36,050       36,000
# 4  III              Daging Sapi            -      118,750      119,300
#
#   06/ 01/ 2021 07/ 01/ 2021 08/ 01/ 2021 11/ 01/ 2021 12/ 01/ 2021  ...  \
# 0       11,800       11,800       11,800       11,800       11,800  ...
# 1       11,850       11,800       11,800       11,800       11,800  ...
# 2       36,100       36,150       35,800       35,700       35,700  ...
# 3       36,100       36,150       35,800       35,700       35,700  ...
# 4      119,400      119,400      119,450      119,350      119,300  ...
#
#   18/ 09/ 2023 19/ 09/ 2023 20/ 09/ 2023 21/ 09/ 2023 22/ 09/ 2023  \
# ...

# %% [markdown]
# ## Menghapus kolom yang tidak diperlukan

# %%
data.drop('No', axis=1, inplace=True)
data.head()
# Out:
#             Komoditas (Rp) 01/ 01/ 2021 04/ 01/ 2021 05/ 01/ 2021  \
# 0                    Beras            -       11,800       11,800
# 1  Beras Kualitas Medium I            -       11,800       11,800
# 2              Daging Ayam            -       36,050       36,000
# 3    Daging Ayam Ras Segar            -       36,050       36,000
# 4              Daging Sapi            -      118,750      119,300
#
#   06/ 01/ 2021 07/ 01/ 2021 08/ 01/ 2021 11/ 01/ 2021 12/ 01/ 2021  \
# 0       11,800       11,800       11,800       11,800       11,800
# 1       11,850       11,800       11,800       11,800       11,800
# 2       36,100       36,150       35,800       35,700       35,700
# 3       36,100       36,150       35,800       35,700       35,700
# 4      119,400      119,400      119,450      119,350      119,300
#
#   13/ 01/ 2021  ... 18/ 09/ 2023 19/ 09/ 2023 20/ 09/ 2023 21/ 09/ 2023  \
# 0       11,800  ...       14,200       14,250       14,250       14,250
# ...

# %% [markdown]
# ## Mengubah struktur dataframe

# %% [markdown]
# ### Transpose dataframe agar tanggal menjadi baris dan komoditas menjadi kolom

# %%
data_transposed = data.T
data_transposed.head()
# Out:
#                      0                        1            2  \
# Komoditas (Rp)   Beras  Beras Kualitas Medium I  Daging Ayam
# 01/ 01/ 2021         -                        -            -
# 04/ 01/ 2021    11,800                   11,800       36,050
# 05/ 01/ 2021    11,800                   11,800       36,000
# 06/ 01/ 2021    11,800                   11,850       36,100
#
#                                     3            4                       5
# Komoditas (Rp)  Daging Ayam Ras Segar  Daging Sapi  Daging Sapi Kualitas 1
# 01/ 01/ 2021                        -            -                       -
# 04/ 01/ 2021                   36,050      118,750                 122,600
# 05/ 01/ 2021                   36,000      119,300                 123,100
# 06/ 01/ 2021                   36,100      119,400                 123,200

# %% [markdown]
# ### Mereset indeks setelah proses transpose

# %%
data_transposed.reset_index(inplace=True)
data_transposed.head()
# Out:
#             index       0                        1            2  \
# 0  Komoditas (Rp)   Beras  Beras Kualitas Medium I  Daging Ayam
# 1    01/ 01/ 2021       -                        -            -
# 2    04/ 01/ 2021  11,800                   11,800       36,050
# 3    05/ 01/ 2021  11,800                   11,800       36,000
# 4    06/ 01/ 2021  11,800                   11,850       36,100
#
#                        3            4                       5
# 0  Daging Ayam Ras Segar  Daging Sapi  Daging Sapi Kualitas 1
# 1                      -            -                       -
# 2                 36,050      118,750                 122,600
# 3                 36,000      119,300                 123,100
# 4                 36,100      119,400                 123,200

# %% [markdown]
# ### Memberikan nama pada kolum (index,0,1,2,3,4,5) agar menjadi baris pertama

# %%
data_transposed.columns = data_transposed.iloc[0]
data_transposed.head()
# Out:
# 0  Komoditas (Rp)   Beras  Beras Kualitas Medium I  Daging Ayam  \
# 0  Komoditas (Rp)   Beras  Beras Kualitas Medium I  Daging Ayam
# 1    01/ 01/ 2021       -                        -            -
# 2    04/ 01/ 2021  11,800                   11,800       36,050
# 3    05/ 01/ 2021  11,800                   11,800       36,000
# 4    06/ 01/ 2021  11,800                   11,850       36,100
#
# 0  Daging Ayam Ras Segar  Daging Sapi  Daging Sapi Kualitas 1
# 0  Daging Ayam Ras Segar  Daging Sapi  Daging Sapi Kualitas 1
# 1                      -            -                       -
# 2                 36,050      118,750                 122,600
# 3                 36,000      119,300                 123,100
# 4                 36,100      119,400                 123,200

# %% [markdown]
# ### Menghapus baris pertama

# %%
data_transposed = data_transposed.drop(0)
data_transposed.head()
# Out:
# 0 Komoditas (Rp)   Beras Beras Kualitas Medium I Daging Ayam  \
# 1   01/ 01/ 2021       -                       -           -
# 2   04/ 01/ 2021  11,800                  11,800      36,050
# 3   05/ 01/ 2021  11,800                  11,800      36,000
# 4   06/ 01/ 2021  11,800                  11,850      36,100
# 5   07/ 01/ 2021  11,800                  11,800      36,150
#
# 0 Daging Ayam Ras Segar Daging Sapi Daging Sapi Kualitas 1
# 1                     -           -                      -
# 2                36,050     118,750                122,600
# 3                36,000     119,300                123,100
# 4                36,100     119,400                123,200
# 5                36,150     119,400                123,250

# %% [markdown]
# ### Reset indeks agar dimulai dari 0 kembali

# %%
data_transposed.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Mengubah kolum 'Komoditas (Rp)' menjadi 'Tanggal'

# %%
data_transposed = data_transposed.rename(columns={'Komoditas (Rp)' : 'Tanggal'})
data_transposed.head()
# Out:
# 0       Tanggal   Beras Beras Kualitas Medium I Daging Ayam  \
# 0  01/ 01/ 2021       -                       -           -
# 1  04/ 01/ 2021  11,800                  11,800      36,050
# 2  05/ 01/ 2021  11,800                  11,800      36,000
# 3  06/ 01/ 2021  11,800                  11,850      36,100
# 4  07/ 01/ 2021  11,800                  11,800      36,150
#
# 0 Daging Ayam Ras Segar Daging Sapi Daging Sapi Kualitas 1
# 0                     -           -                      -
# 1                36,050     118,750                122,600
# 2                36,000     119,300                123,100
# 3                36,100     119,400                123,200
# 4                36,150     119,400                123,250

# %%
data_transposed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 716 entries, 0 to 715
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Tanggal                  716 non-null    object
#  1   Beras                    716 non-null    object
#  2   Beras Kualitas Medium I  716 non-null    object
#  3   Daging Ayam              716 non-null    object
#  4   Daging Ayam Ras Segar    716 non-null    object
#  5   Daging Sapi              716 non-null    object
#  6   Daging Sapi Kualitas 1   716 non-null    object
# dtypes: object(7)
# memory usage: 39.3+ KB

# %% [markdown]
# ## Menyeleksi kolum yang akan digunakan

# %%
# Karena pada tugas diperlukan 1 kategori
# Maka disini akan memilih satu kategori
# Diantara 7 kolom yaitu Beras
df = data_transposed.drop(['Beras Kualitas Medium I',
                           'Daging Ayam','Daging Ayam Ras Segar',
                           'Daging Sapi',
                           'Daging Sapi Kualitas 1'],
                          axis=1)
df.head()
# Out:
# 0       Tanggal   Beras
# 0  01/ 01/ 2021       -
# 1  04/ 01/ 2021  11,800
# 2  05/ 01/ 2021  11,800
# 3  06/ 01/ 2021  11,800
# 4  07/ 01/ 2021  11,800

# %% [markdown]
# ^ Di atas ada data yang nilainya kosong yaitu '-' ini perlu diubah ^

# %% [markdown]
# ## Mengatasi Missing Value

# %%
# Mengatasi nilai kosong
df = df.replace('-', 0)
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 716 entries, 0 to 715
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Tanggal  716 non-null    object
#  1   Beras    716 non-null    object
# dtypes: object(2)
# memory usage: 11.3+ KB
# None
# 0       Tanggal   Beras
# 0  01/ 01/ 2021       0
# 1  04/ 01/ 2021  11,800
# 2  05/ 01/ 2021  11,800
# 3  06/ 01/ 2021  11,800
# 4  07/ 01/ 2021  11,800

# %% [markdown]
# ^ Di atas Nilai yang '-' Di ubah menjadi 0 agar kolum Beras dapat di ubah ke tipe data numerik, dimana awalnya adalah object ^

# %%
# Mengubah tipe data kolum "Beras" dari object menjadi float
# Dan disini yang nilainya 0 akan menjadi null
df['Beras'] = df['Beras'].str.replace(',','').astype(float)
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 716 entries, 0 to 715
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Tanggal  716 non-null    object
#  1   Beras    706 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 11.3+ KB
# None
# 0       Tanggal    Beras
# 0  01/ 01/ 2021      NaN
# 1  04/ 01/ 2021  11800.0
# 2  05/ 01/ 2021  11800.0
# 3  06/ 01/ 2021  11800.0
# 4  07/ 01/ 2021  11800.0

# %% [markdown]
# ^ Jika dilihat pada info() kolum 'Beras' sudah berubah menjadi float ^

# %%
# Mengecek Missing Value pada data
df.isna().sum()
# Out:
# 0
# Tanggal     0
# Beras      10
# dtype: int64

# %% [markdown]
# ^ Di atas terdapat 10 baris pada kolom Beras yang memiliki nilai null ^

# %%
# Mengatasi missing value dengan mengisi nilai null
# Menggunakan rata-rata kolum beras
mean_harga_beras = int(df['Beras'].mean())
df_non_null = df.fillna(mean_harga_beras)
print('Nilai Null Pada Kolum Beras :', df_non_null['Beras'].isna().sum())
df_non_null
# Out:
# Nilai Null Pada Kolum Beras : 0
# 0         Tanggal    Beras
# 0    01/ 01/ 2021  12292.0
# 1    04/ 01/ 2021  11800.0
# 2    05/ 01/ 2021  11800.0
# 3    06/ 01/ 2021  11800.0
# 4    07/ 01/ 2021  11800.0
# ..            ...      ...
# 711  25/ 09/ 2023  14350.0
# 712  26/ 09/ 2023  14350.0
# 713  27/ 09/ 2023  14350.0
# 714  28/ 09/ 2023  14400.0
# 715  29/ 09/ 2023  14400.0
#
# [716 rows x 2 columns]

# %% [markdown]
# ## Mengubah tipe data 'Tanggal'

# %%
# Mengubah dtype Tanggal dari object ke datetime
df_clean = df_non_null

# Menghapus spasi yang ada pada tanggal and konversi "Tanggal" ke datetime
df_clean["Tanggal"] = pd.to_datetime(df_clean["Tanggal"].str.replace(' ', ''), format="%d/%m/%Y")

# %%
print(df_clean.info())
df_clean.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 716 entries, 0 to 715
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Tanggal  716 non-null    datetime64[ns]
#  1   Beras    716 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 11.3 KB
# None
# 0    Tanggal    Beras
# 0 2021-01-01  12292.0
# 1 2021-01-04  11800.0
# 2 2021-01-05  11800.0
# 3 2021-01-06  11800.0
# 4 2021-01-07  11800.0

# %% [markdown]
# ## Ekstrasi dan data splitting

# %%
# Ekstrasi fitur dari kolum 'Tanggal'
df_clean["Year"] = df_clean["Tanggal"].dt.year
df_clean["Month"] = df_clean["Tanggal"].dt.month
df_clean["Day"] = df_clean["Tanggal"].dt.day
df_clean["DayOfYear"] = df_clean["Tanggal"].dt.dayofyear
df_clean.head()
# Out:
# 0    Tanggal    Beras  Year  Month  Day  DayOfYear
# 0 2021-01-01  12292.0  2021      1    1          1
# 1 2021-01-04  11800.0  2021      1    4          4
# 2 2021-01-05  11800.0  2021      1    5          5
# 3 2021-01-06  11800.0  2021      1    6          6
# 4 2021-01-07  11800.0  2021      1    7          7

# %%
# Assign variabel Fitur dan Target
X = df_clean[["Year", "Month", "Day", "DayOfYear"]]
y = df_clean["Beras"]

# %%
# Split data training dan testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# ## Model Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
# Pemodelan dengan naiive bayes
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# ## Evaluasi Model

# %%
# Evaluasi model
prediksi = model.predict(X_test)
accuracy = (prediksi == y_test).mean()
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 66.67%

# %% [markdown]
# ### Prediksi harga beras 30 hari ke depan

# %%
# Membuat data 30 hari ke depan
import numpy as np
tanggal_kedepan = pd.date_range(start=df_clean["Tanggal"].max(), periods=30, freq='D')
tanggal_kedepan
# Out:
# DatetimeIndex(['2023-09-29', '2023-09-30', '2023-10-01', '2023-10-02',
#                '2023-10-03', '2023-10-04', '2023-10-05', '2023-10-06',
#                '2023-10-07', '2023-10-08', '2023-10-09', '2023-10-10',
#                '2023-10-11', '2023-10-12', '2023-10-13', '2023-10-14',
#                '2023-10-15', '2023-10-16', '2023-10-17', '2023-10-18',
#                '2023-10-19', '2023-10-20', '2023-10-21', '2023-10-22',
#                '2023-10-23', '2023-10-24', '2023-10-25', '2023-10-26',
#                '2023-10-27', '2023-10-28'],
#               dtype='datetime64[ns]', freq='D')

# %%
# Membuat fitur data 30 hari ke depan
data_kedepan = pd.DataFrame({
    "Tanggal": tanggal_kedepan,
    "Year": tanggal_kedepan.year,
    "Month": tanggal_kedepan.month,
    "Day": tanggal_kedepan.day,
    "DayOfYear": tanggal_kedepan.dayofyear
})
data_kedepan.head()
# Out:
#      Tanggal  Year  Month  Day  DayOfYear
# 0 2023-09-29  2023      9   29        272
# 1 2023-09-30  2023      9   30        273
# 2 2023-10-01  2023     10    1        274
# 3 2023-10-02  2023     10    2        275
# 4 2023-10-03  2023     10    3        276

# %%
# Prediksi harga beras 30 hari ke depan
prediksi_kedepan = model.predict(data_kedepan[["Year", "Month", "Day", "DayOfYear"]])
prediksi_kedepan
# Out:
# array([14400., 14400., 13750., 13600., 13600., 13600., 13600., 13600.,
#        13600., 14150., 14150., 14150., 14150., 14150., 14150., 14150.,
#        14150., 14150., 14150., 14150., 14150., 14150., 14150., 14150.,
#        14150., 14150., 13650., 13650., 13650., 13650.])

# %%
# Merge prediksi harga beras dan fitur
data_kedepan["Predicted_Beras"] = prediksi_kedepan
data_kedepan
# Out:
#       Tanggal  Year  Month  Day  DayOfYear  Predicted_Beras
# 0  2023-09-29  2023      9   29        272          14400.0
# 1  2023-09-30  2023      9   30        273          14400.0
# 2  2023-10-01  2023     10    1        274          13750.0
# 3  2023-10-02  2023     10    2        275          13600.0
# 4  2023-10-03  2023     10    3        276          13600.0
# 5  2023-10-04  2023     10    4        277          13600.0
# 6  2023-10-05  2023     10    5        278          13600.0
# 7  2023-10-06  2023     10    6        279          13600.0
# 8  2023-10-07  2023     10    7        280          13600.0
# 9  2023-10-08  2023     10    8        281          14150.0
# 10 2023-10-09  2023     10    9        282          14150.0
# 11 2023-10-10  2023     10   10        283          14150.0
# 12 2023-10-11  2023     10   11        284          14150.0
# 13 2023-10-12  2023     10   12        285          14150.0
# 14 2023-10-13  2023     10   13        286          14150.0
# ...

# %%
# Konversi "Tanggal"
data_kedepan["Tanggal"] = data_kedepan["Tanggal"].dt.strftime("%d/%m/%Y")

# %%
data_kedepan
# Out:
#        Tanggal  Year  Month  Day  DayOfYear  Predicted_Beras
# 0   29/09/2023  2023      9   29        272          14400.0
# 1   30/09/2023  2023      9   30        273          14400.0
# 2   01/10/2023  2023     10    1        274          13750.0
# 3   02/10/2023  2023     10    2        275          13600.0
# 4   03/10/2023  2023     10    3        276          13600.0
# 5   04/10/2023  2023     10    4        277          13600.0
# 6   05/10/2023  2023     10    5        278          13600.0
# 7   06/10/2023  2023     10    6        279          13600.0
# 8   07/10/2023  2023     10    7        280          13600.0
# 9   08/10/2023  2023     10    8        281          14150.0
# 10  09/10/2023  2023     10    9        282          14150.0
# 11  10/10/2023  2023     10   10        283          14150.0
# 12  11/10/2023  2023     10   11        284          14150.0
# 13  12/10/2023  2023     10   12        285          14150.0
# ...

# %% [markdown]
# ## Visualisasi Data Prediksi

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Melt DataFrame untuk merubah data menjadi format long
df_future = data_kedepan.melt(id_vars=['Tanggal'], value_vars=['Predicted_Beras'],
                     var_name='Komoditas', value_name='Harga')


# Plot menggunakan Seaborn
plt.figure(figsize=(15, 6))
sns.set_style("dark")
ax = sns.lineplot(
    data=df_future, 
    x='Tanggal', 
    y='Harga', 
    hue='Komoditas',
    palette="rocket"
)
plt.xlabel('Tanggal')
plt.ylabel('Harga')
plt.title('Visualisasi Time Series Harga Beras Setelah di Prediksi')
plt.legend(title='Komoditas')
plt.grid(True)
ax.set_facecolor('white')
ax.figure.set_facecolor('white')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data_kedepan['Tanggal'],data_kedepan['Predicted_Beras'], color='Orange')


plt.title('Prediksi Harga Beras')
plt.xlabel('Tanggal') 
plt.ylabel('Harga Beras') 

plt.xticks(rotation=90) 
plt.gca().xaxis.set_major_locator(plt.MaxNLocator(30)) 

# Mengatur Skala interval pada sumbu y
plt.gca().yaxis.set_major_locator(plt.MaxNLocator(20)) 
plt.tight_layout() 

plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(data_kedepan['Tanggal'], data_kedepan['Predicted_Beras'], color='Orange')

plt.title('Prediksi Harga Beras')
plt.xlabel('Tanggal') 
plt.ylabel('Harga Beras') 

plt.xticks(rotation=90)
plt.gca().xaxis.set_major_locator(plt.MaxNLocator(30))

# Mengatur Skala interval pada sumbu y
plt.gca().yaxis.set_major_locator(plt.MaxNLocator(20))
plt.tight_layout()

plt.grid(True)
plt.show()

# %% [markdown]
# ## Menyimpan hasil prediksi ke CSV

# %%
data_kedepan.to_csv('prediksi_beras_naive_bayes.csv')
